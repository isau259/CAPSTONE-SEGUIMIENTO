# %%
import funciones_2 as fn2
print(fn2.listar_funciones())
# Out:
# calcular_baseline_y_alertas
# crear_variable
# listar_funciones
# procesamiento
# viewer_plotly_params_from_df
# None

# %%
def deteccion(sub, ses, run, seg):
    datos = fn2.crear_variable(sub, ses, run, seg)
    df = fn2.procesamiento(datos, win_size=60, step=15, smooth_n=5, overview_ds=10)
    df_alertas = fn2.calcular_baseline_y_alertas( df, baseline_duration_sec=1800, persistence_sec=60)
    
    fn2.viewer_plotly_params_from_df(
        df_alertas,
        metrics=(
            "ALERTA_CONSENSO",
            "ALERTA_PERSISTENTE",
        ),
        default_metric="ALERTA_PERSISTENTE",
        default_smooth=1,
        open_in_browser=True
    )

# %%
deteccion(sub=28, ses=1, run=1, seg=0)
# Out:
# fs=256.0 Hz | duración=1829.0 s | muestras=468,224
# onset=4980.00s | offset=5009.00s | cut_start=4080.00s
# Total de ventanas: 118 (win=60s, step=15s)
# /opt/miniconda3/lib/python3.13/site-packages/neurokit2/hrv/hrv_nonlinear.py:536: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# /opt/miniconda3/lib/python3.13/site-packages/neurokit2/hrv/hrv_nonlinear.py:536: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# ...
